# %%
import os
import numpy as np
import pandas as pd

from tqdm.notebook import tqdm

# %%
train = pd.read_csv('../data/train.csv')
train_ = train.drop(columns = ['id', 'digit', 'letter'])

test = pd.read_csv('../data/test.csv')
sample = pd.read_csv('../data/submission.csv')

# %%
def img_save(dataset, isTrain=True):
    for i in tqdm(range(len(dataset))):
        id_ = dataset.iloc[i]['id']
        letter_ = data.iloc[i]['letter']
        img_array = np.array(dataset.iloc[i]).reshape((28, 28)).astype('uint8')
        img = Image.fromarray(img_array)
        if isTrain:
            digit_ = dataset.iloc[i]['digit']
            if not os.path.exists(os.path.join('../data/train/', digit_)):
                os.mkdir(os.path.join('../data/train/', digit_))
            img.save(os.path.join(f'../data/train/{digit_}/', f'{id_}_{letter_}.jpg'))
        else:
            img.save(os.path.join(f'../data/test/{digit_}/', f'{id_}_{letter_}.jpg'))

# %%
for i in tqdm(range(len(train))):
    id_ = train.iloc[i]['id']
    digit_ = train.iloc[i]['digit']
    img_array = np.array(train_.iloc[i]).reshape((28, 28)).astype('uint8')
    img = Image.fromarray(img_array)
    if not os.path.exists(os.path.join('../data/train/', digit_)):
        os.mkdir(os.path.join('../data/train/', digit_))

# %%
train.head()
# Out:
#    id  digit letter  0  1  2  3  4  5  6  ...  774  775  776  777  778  779  \
# 0   1      5      L  1  1  1  4  3  0  0  ...    2    1    0    1    2    4
# 1   2      0      B  0  4  0  0  4  1  1  ...    0    3    0    1    4    1
# 2   3      4      L  1  1  2  2  1  1  1  ...    3    3    3    0    2    0
# 3   4      9      D  1  2  0  2  0  4  0  ...    3    3    2    0    1    4
# 4   5      6      A  3  0  2  4  0  3  0  ...    4    4    3    2    1    3
#
#    780  781  782  783
# 0    4    4    3    4
# 1    4    2    1    2
# 2    3    0    2    2
# 3    0    0    1    1
# 4    4    3    1    2
#
# [5 rows x 787 columns]

# %%
from PIL import Image

img = Image.fromarray()

# %%
img.save()
# Out:
# <PIL.Image.Image image mode=L size=28x28 at 0x7FE8B289C390>
